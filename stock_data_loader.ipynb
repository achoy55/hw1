# %%
import yfinance as yf
import pandas as pd
from datetime import timedelta, datetime
import os

print("yfinance version: {}".format(yf.__version__))
# Out:
# yfinance version: 0.2.47

# %%
table = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = table[0]
stock_symbols = df['Symbol'].to_list()
stock_symbols.remove('BF.B')
stock_symbols.remove('BRK.B')

delta = timedelta(days=-1200) # 5y
today = datetime.now()

# %%
print("Start load stock data with interval: " + time_interval)
data = yf.download(stock_symbols, today+delta, interval=time_interval)
data.columns = pd.MultiIndex.from_tuples([i[::-1] for i in data.columns])
# data.head
data.info
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 2 Failed downloads:
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2021-12-02 23:20:53.537644 -> 2024-11-16)')
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# <bound method DataFrame.info of                                     A        AAPL        ABBV        ABNB  \
#                             Adj Close   Adj Close   Adj Close   Adj Close
# Date
# 2021-12-03 00:00:00+00:00  146.346436  159.231659  106.073807  166.750000
# 2021-12-06 00:00:00+00:00  148.443726  162.655563  108.305069  180.850006
# 2021-12-07 00:00:00+00:00  150.727142  168.421158  108.447876  183.139999
# 2021-12-08 00:00:00+00:00  153.186996  172.258286  108.769157  186.490005
# 2021-12-09 00:00:00+00:00  151.520950  171.746658  110.804077  181.460007
# ...                               ...         ...         ...         ...
# ...

# %%
data.isna().sum()
# Out:
# A     Adj Close    0
# AAPL  Adj Close    0
# ABBV  Adj Close    0
# ABNB  Adj Close    0
# ABT   Adj Close    0
#                   ..
# XYL   Volume       0
# YUM   Volume       0
# ZBH   Volume       0
# ZBRA  Volume       0
# ZTS   Volume       0
# Length: 3018, dtype: int64

# %%
#Should be ${workspaceFolder} in vscode://settings/jupyter.notebookFileRoot 
save_location = "stock_data"
if not os.path.exists(save_location) :
    os.makedirs(save_location)
    print("Directory '%s' created" % save_location)

# %%
for i in stock_symbols:
    try:
        TEMP = data[i].copy(deep=True)
        TEMP = TEMP.dropna()
        TEMP.to_csv(save_location+"/"+i+".csv")
    except:
        print("Unable to load data for {}".format(i))

print("Download stock data completed")

# %%
# msft = yf.Ticker("MSFT")
# msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...
